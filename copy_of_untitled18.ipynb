# %% [markdown]
# <a href="https://colab.research.google.com/github/Eman-diab-hussein/deep/blob/main/copy_of_untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler

# %%
#https://www.kaggle.com/datasets/dark06thunder/credit-card-dataset?resource=download
data = pd.read_csv('/content/archive.zip')

df = pd.DataFrame(data)

df.head(10)
# Out:
#    Unnamed: 0       ID GENDER CAR REALITY  NO_OF_CHILD    INCOME  \
# 0           0  5008806      M   Y       Y            0  112500.0
# 1           1  5008808      F   N       Y            0  270000.0
# 2           2  5008809      F   N       Y            0  270000.0
# 3           3  5008810      F   N       Y            0  270000.0
# 4           4  5008811      F   N       Y            0  270000.0
# 5           5  5008815      M   Y       Y            0  270000.0
# 6           6  5112956      M   Y       Y            0  270000.0
# 7           7  5008819      M   Y       Y            0  135000.0
# 8           8  5008820      M   Y       Y            0  135000.0
# 9           9  5008821      M   Y       Y            0  135000.0
#
#             INCOME_TYPE                 EDUCATION_TYPE           FAMILY_TYPE  \
# 0               Working  Secondary / secondary special               Married
# 1  Commercial associate  Secondary / secondary special  Single / not married
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25134 entries, 0 to 25133
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      25134 non-null  int64
#  1   ID              25134 non-null  int64
#  2   GENDER          25134 non-null  object
#  3   CAR             25134 non-null  object
#  4   REALITY         25134 non-null  object
#  5   NO_OF_CHILD     25134 non-null  int64
#  6   INCOME          25134 non-null  float64
#  7   INCOME_TYPE     25134 non-null  object
#  8   EDUCATION_TYPE  25134 non-null  object
#  9   FAMILY_TYPE     25134 non-null  object
#  10  HOUSE_TYPE      25134 non-null  object
#  11  FLAG_MOBIL      25134 non-null  int64
#  12  WORK_PHONE      25134 non-null  int64
#  13  PHONE           25134 non-null  int64
#  14  E_MAIL          25134 non-null  int64
#  15  FAMILY SIZE     25134 non-null  float64
#  16  BEGIN_MONTH     25134 non-null  int64
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (25134, 20)

# %%
df['TARGET'].value_counts()
# Out:
# TARGET
# 0    24712
# 1      422
# Name: count, dtype: int64

# %%
df = pd.get_dummies(df, columns=['REALITY','GENDER',	'CAR','INCOME_TYPE','EDUCATION_TYPE','FAMILY_TYPE','HOUSE_TYPE'])
df_encoded = pd.get_dummies(df, columns=df, drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-f8f2a7d8df6f> in <cell line: 2>()
#       1 df = pd.get_dummies(df, columns=['REALITY','GENDER',    'CAR','INCOME_TYPE','EDUCATION_TYPE','FAMILY_TYPE','HOUSE_TYPE'])
# ----> 2 df_encoded = pd.get_dummies(df, columns=df, drop_first=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/encoding.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     156             raise TypeError("Input must be a list-like for parameter `columns`")
#     157         else:
# --> 158             data_to_encode = data[columns]
#     159
#     160         # validate prefixes and separator to avoid silently dropping cols
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3746         # Do we have a (boolean) DataFrame?
# ...

# %%
import pandas as pd

# Assuming your DataFrame is named df
# Select categorical columns to one-hot encode
categorical_cols = ['GENDER', 'CAR', 'REALITY', 'INCOME_TYPE', 'EDUCATION_TYPE', 'FAMILY_TYPE', 'HOUSE_TYPE']

# Apply one-hot encoding to the selected columns
df= pd.get_dummies(df, columns=categorical_cols, drop_first=True)

# %%
scaler = MinMaxScaler()
columns_to_normalize = ['ID','INCOME','BEGIN_MONTH']
df[columns_to_normalize] = scaler.fit_transform(df[columns_to_normalize])
df.head(10)
# Out:
#    Unnamed: 0        ID  NO_OF_CHILD    INCOME  FLAG_MOBIL  WORK_PHONE  PHONE  \
# 0           0  0.000000            0  0.055233           1           0      0
# 1           1  0.000014            0  0.156977           1           0      1
# 2           2  0.000021            0  0.156977           1           0      1
# 3           3  0.000028            0  0.156977           1           0      1
# 4           4  0.000035            0  0.156977           1           0      1
# 5           5  0.000064            0  0.156977           1           1      1
# 6           6  0.735102            0  0.156977           1           1      1
# 7           7  0.000092            0  0.069767           1           0      0
# 8           8  0.000099            0  0.069767           1           0      0
# 9           9  0.000106            0  0.069767           1           0      0
#
#    E_MAIL  FAMILY SIZE  BEGIN_MONTH  ...  \
# 0       0          2.0     0.483333  ...
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                                        int64
# ID                                              float64
# NO_OF_CHILD                                       int64
# INCOME                                          float64
# FLAG_MOBIL                                        int64
# WORK_PHONE                                        int64
# PHONE                                             int64
# E_MAIL                                            int64
# FAMILY SIZE                                     float64
# BEGIN_MONTH                                     float64
# AGE                                               int64
# YEARS_EMPLOYED                                    int64
# TARGET                                            int64
# GENDER_M                                           bool
# CAR_Y                                              bool
# REALITY_Y                                          bool
# INCOME_TYPE_Pensioner                              bool
# ...
